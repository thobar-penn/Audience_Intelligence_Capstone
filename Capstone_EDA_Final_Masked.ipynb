# %% [markdown]
# ## EDA

# %%
from pyspark.sql import functions as F
from pyspark.sql.window import Window
import pandas as pd
import plotly.express as px

# %%
# Tier distribution by Education Level & Income Group

df=spark.table("XXX").toPandas()

for c in ['XXX', 'XXX']:
    tmp = (df
           .groupby(['Tier', c], dropna=False)
           .size()
           .reset_index(name='count'))
    
    tmp['% of Tier'] = tmp['count'] / tmp.groupby('Tier')['count'].transform('sum')*100

    fig = px.bar(tmp,
        x=c,
        y='% of Tier',
        color="Tier",
        barmode="group",         
        text_auto=False,
        title=f"Distribution of {c} across Tiers",
        labels={c:"Education Level","count":"x"},
        #labels={c:"Income Group","count":"x"},
    )
    fig.update_layout(
        template="plotly_white",
        bargap=0.05,
        xaxis_tickangle=-30,
        height=500,
        width=900,
          yaxis=dict(showticklabels=False),
                   showlegend=False)
    
    fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.12.1.min.js"></script>                <div id="c6abecaa-cb72-449a-b107-e15dfe077715" class="plotly-graph-div" style="height:500px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c6abecaa-cb72-449a-b107-e15dfe077715")) {                    Plotly.newPlot(                        "c6abecaa-cb72-449a-b107-e15dfe077715",                        [{"alignmentgroup":"True","hovertemplate":"Tier=Mid-Market<br>Education Level=%{x}<br>% of Tier=%{y}<extra></extra>","legendgroup":"Mid-Market","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Mid-Market","offsetgroup":"Mid-Market","orientation":"v","showlegend":true,"textposition":"auto","x":["1","2","3","4",null],"xaxis":"x","y":[39.50144114668536,27.419698268027314,18.550024668276595,0.3733998078471086,14.155436109163617],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tier=Non-Standard<br>Education Level=%{x}<br>% of Tier=%{y}<extra></extra>","legendgroup":"Non-Standard","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Non-Standard","offsetgroup":"Non-Standard","orientation":"v","showlegend":true,"textposition":"auto","x":["1","2","3","4",null],"xaxis":"x","y":[42.165890027958994,20.663560111835974,9.726001863932899,0.5778191985088537,26.86672879776328],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tier=Preferred<br>Education Level=%{x}<br>% of Tier=%{y}<extra></extra>","legendgroup":"Preferred","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Preferred","offsetgroup":"Preferred","orientation":"v","showlegend":true,"textposition":"auto","x":["1","2","3","4",null],"xaxis":"x","y":[42.576105406231505,25.28565947179824,16.817002347707895,0.34012499430957227,14.981107779952785],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tier=Standard<br>Education Level=%{x}<br>% of Tier=%{y}<extra></extra>","legendgroup":"Standard","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Standard","offsetgroup":"Standard","orientation":"v","showlegend":true,"textposition":"auto","x":["1","2","3","4",null],"xaxis":"x","y":[42.27144618636604,24.785684927485175,13.85414831777347,0.47560331160824376,18.613117256767072],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tier=UltraPreferred<br>Education Level=%{x}<br>% of Tier=%{y}<extra></extra>","legendgroup":"UltraPreferred","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"UltraPreferred","offsetgroup":"UltraPreferred","orientation":"v","showlegend":true,"textposition":"auto","x":["1","2","3","4",null],"xaxis":"x","y":[42.284306195596514,24.862391193036355,18.627325482164192,0.26561699948796724,13.960360129714969],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.777777777 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.12.1.min.js"></script>                <div id="bd5ce613-9c74-4bd6-9269-e469b94c4012" class="plotly-graph-div" style="height:500px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bd5ce613-9c74-4bd6-9269-e469b94c4012")) {                    Plotly.newPlot(                        "bd5ce613-9c74-4bd6-9269-e469b94c4012",                        [{"alignmentgroup":"True","hovertemplate":"Tier=Mid-Market<br>Education Level=%{x}<br>% of Tier=%{y}<extra></extra>","legendgroup":"Mid-Market","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Mid-Market","offsetgroup":"Mid-Market","orientation":"v","showlegend":true,"textposition":"auto","x":["1","2","3","4","5","6","7","8","9",null],"xaxis":"x","y":[0.9825764067409312,0.8413180649684505,2.4569603489911973,2.8272441640050894,4.345252005920386,11.311573316714703,13.882267404118304,12.729869387967074,49.555192023058346,1.067746877515515],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tier=Non-Standard<br>Education Level=%{x}<br>% of Tier=%{y}<extra></extra>","legendgroup":"Non-Standard","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Non-Standard","offsetgroup":"Non-Standard","orientation":"v","showlegend":true,"textposition":"auto","x":["1","2","3","4","5","6","7","8","9",null],"xaxis":"x","y":[3.0792171481826656,2.7101584342963654,6.0577819198508855,6.4492078285181735,8.14165890027959,17.319664492078285,17.01397949673812,12.45107176141659,26.12115563839702,0.6561043802423113],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tier=Preferred<br>Education Level=%{x}<br>% of Tier=%{y}<extra></extra>","legendgroup":"Preferred","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Preferred","offsetgroup":"Preferred","orientation":"v","showlegend":true,"textposition":"auto","x":["1","2","3","4","5","6","7","8","9",null],"xaxis":"x","y":[0.7960095469118862,0.7374794331683652,2.288527447371673,2.7366079848081837,4.206364174367712,11.477104970507327,14.270292065267581,13.143912543003374,49.51712656161595,0.8265752729779471],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tier=Standard<br>Education Level=%{x}<br>% of Tier=%{y}<extra></extra>","legendgroup":"Standard","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Standard","offsetgroup":"Standard","orientation":"v","showlegend":true,"textposition":"auto","x":["1","2","3","4","5","6","7","8","9",null],"xaxis":"x","y":[1.7688333039751043,1.6000234865832894,3.872350419822676,4.3890552521871875,5.909811520169103,14.11396864541131,15.800598907873878,12.922024543479537,38.7587340731607,0.8645998473372086],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tier=UltraPreferred<br>Education Level=%{x}<br>% of Tier=%{y}<extra></extra>","legendgroup":"UltraPreferred","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"UltraPreferred","offsetgroup":"UltraPreferred","orientation":"v","showlegend":true,"textposition":"auto","x":["1","2","3","4","5","6","7","8","9",null],"xaxis":"x","y":[0.47149684246458434,0.4458952039597201,1.6801075268817203,1.9329237071172556,3.398617511520737,9.337130909711554,12.423195084485407,12.355990783410139,57.05538487796552,0.8992575524833589],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f" ...

# %%
# Average Loss Ratio by Occupation

avg_df = (
    pdf.groupby("Occupation_-_Person", as_index=False)
       .agg(avg_loss_ratio=("LossRatio", "mean"),
            count=("LossRatio", "size"))
)

fig = px.bar(
    avg_df.sort_values("avg_loss_ratio", ascending=False),
    x="Occupation_-_Person",
    y="avg_loss_ratio",
    color="avg_loss_ratio",
    title=f"Average Loss Ratio by Occupation",
    labels={"avg_loss_ratio": "Average Loss Ratio", "Occupation_-_Person": "Occupation"}
)
fig.update_layout(template="plotly_white", xaxis_tickangle=-45, height=600, width=900, showlegend=False,#xaxis=dict(showticklabels=False),
                   yaxis=dict(showticklabels=False))

overall_mean = pdf["LossRatio"].mean()

fig.add_hline(y=overall_mean, line_color="black", line_dash="dash",
              annotation_text="Overall mean", annotation_position="top left")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.12.1.min.js"></script>                <div id="1b10f5c6-57f9-4585-aa2b-f399f2b139fc" class="plotly-graph-div" style="height:600px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1b10f5c6-57f9-4585-aa2b-f399f2b139fc")) {                    Plotly.newPlot(                        "1b10f5c6-57f9-4585-aa2b-f399f2b139fc",                        [{"alignmentgroup":"True","hovertemplate":"Occupation=%{x}<br>Average Loss Ratio=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[0.286987220473216,0.28601981732388215,0.27699476511273574,0.17457560789918602,0.1457220563992304,0.1277134314768601,0.12632950187970388,0.12323848876226039,0.12242308610316835,0.1190316314115527,0.11890390481265077,0.1161145555253553,0.11561431533286952,0.11513057529907346,0.11412643520864268,0.11327744399990837,0.10945605468797695,0.10765586281314378,0.10486246515933483,0.10455822658789271,0.08186284699283414,0.07956173029833477,0.07766996354184157,0.0476091871056026,0.037265051377575444,0.004269617319079256],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["B","J","I","E","A","7","Y","9","4","5","8","1","Z","3","2","X","6","W","V","C","D","G","K","H","F","L"],"xaxis":"x","y":[0.286987220473216,0.28601981732388215,0.27699476511273574,0.17457560789918602,0.1457220563992304,0.1277134314768601,0.12632950187970388,0.12323848876226039,0.12242308610316835,0.1190316314115527,0.11890390481265077,0.1161145555253553,0.11561431533286952,0.11513057529907346,0.11412643520864268,0.11327744399990837,0.10945605468797695,0.10765586281314378,0.10486246515933483,0.10455822658789271,0.08186284699283414,0.07956173029833477,0.07766996354184157,0.0476091871056026,0.037265051377575444,0.004269617319079256],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth ...

# %%
# Behavior propensities by tier

TIER_COL = "XXX"

# Combine
heat = pd.concat(rows, ignore_index=True) if rows else pd.DataFrame(columns=["behavior", TIER_COL, "pct"])

heat = heat.head(50)

# --- ANONYMIZE LABELS ---
unique_behaviors = heat["behavior"].unique().tolist()
unique_tiers = heat[TIER_COL].unique().tolist()

anon_tier_map = {b: f"Tier {chr(65+i)}" for i, b in enumerate(unique_tiers)}
anon_behavior_map  = {t: f"Behavior {i+1}" for i, t in enumerate(unique_behaviors)}

heat["behavior_anon"] = heat["behavior"].map(anon_behavior_map)
heat["tier_anon"] = heat[TIER_COL].map(anon_tier_map)

# --- HEATMAP ---
fig = px.density_heatmap(
    heat,
    x="tier_anon",
    y="behavior_anon",
    z="pct",
    color_continuous_scale="Viridis",
   # title="Relative High-Propensity Share by Tier and Behavior"
)

# --- LAYOUT CLEANUP ---
fig.update_layout(
    template="plotly_white",
    xaxis_title="Tier",
    yaxis_title="Behavior",
    height=450 + 20 * len(unique_behaviors),
    width=1000,
    coloraxis_showscale=True

)

fig.update_coloraxes(

        colorbar=dict(
            title="",
            tickvals=[heat["pct"].min(), heat['pct'].max()],
            ticktext=["Low", "High"],
            ticks='outside',
            showticklabels=True)
)

# Optional: hide axis tick labels for masking
#fig.update_xaxes(showticklabels=False)
#fig.update_yaxes(showticklabels=False)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.12.1.min.js"></script>                <div id="1bcd1558-b5f2-4085-875b-f48f0f8d14e8" class="plotly-graph-div" style="height:650px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1bcd1558-b5f2-4085-875b-f48f0f8d14e8")) {                    Plotly.newPlot(                        "1bcd1558-b5f2-4085-875b-f48f0f8d14e8",                        [{"coloraxis":"coloraxis","histfunc":"sum","hovertemplate":"tier_anon=%{x}<br>behavior_anon=%{y}<br>sum of pct=%{z}<extra></extra>","name":"","x":["Tier A","Tier B","Tier C","Tier D","Tier E","Tier A","Tier B","Tier C","Tier D","Tier E","Tier A","Tier B","Tier C","Tier D","Tier E","Tier A","Tier B","Tier C","Tier D","Tier E","Tier A","Tier B","Tier C","Tier D","Tier E","Tier A","Tier B","Tier C","Tier D","Tier E","Tier A","Tier B","Tier C","Tier D","Tier E","Tier A","Tier B","Tier C","Tier D","Tier E","Tier A","Tier B","Tier C","Tier D","Tier E","Tier A","Tier B","Tier C","Tier D","Tier E"],"xaxis":"x","xbingroup":"x","y":["Behavior 1","Behavior 1","Behavior 1","Behavior 1","Behavior 1","Behavior 2","Behavior 2","Behavior 2","Behavior 2","Behavior 2","Behavior 3","Behavior 3","Behavior 3","Behavior 3","Behavior 3","Behavior 4","Behavior 4","Behavior 4","Behavior 4","Behavior 4","Behavior 5","Behavior 5","Behavior 5","Behavior 5","Behavior 5","Behavior 6","Behavior 6","Behavior 6","Behavior 6","Behavior 6","Behavior 7","Behavior 7","Behavior 7","Behavior 7","Behavior 7","Behavior 8","Behavior 8","Behavior 8","Behavior 8","Behavior 8","Behavior 9","Behavior 9","Behavior 9","Behavior 9","Behavior 9","Behavior 10","Behavior 10","Behavior 10","Behavior 10","Behavior 10"],"yaxis":"y","ybingroup":"y","z":[0.30366315546003875,0.3285756965392288,0.19186993436966934,0.04863968852095641,0.12725152511010668,0.27906058939604694,0.4017856565199107,0.15817293695209136,0.03812635460809368,0.12285446252385727,0.30151341838979323,0.38634403871535417,0.19019797624285087,0.026511218653761548,0.09543334799824021,0.27459836975603275,0.31854283897782376,0.13851380203638158,0.09243426359090176,0.17591072563886015,0.28134369575508916,0.32625848193151336,0.16162024617326812,0.0752327599810636,0.1555448161590658,0.2781521435250793,0.40733242714328405,0.16370226836721904,0.0323818337816082,0.11843132718280938,0.26632225806169635,0.3310431035236322,0.13612881231479296,0.09123331497652952,0.175272511123349,0.2945875046844049,0.3845352178025233,0.1927726323678998,0.026853685957492372,0.10125095918767957,0.29559484395424057,0.36182007270368005,0.20965756757530365,0.03088475226364148,0.10204276350313428,0.2939391940908791,0.3223059420958913,0.1875206093780914,0.0600474840071226,0.13618677042801555],"type":"histogram2d"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"# ...

# %%
# Tier distribution by policy renewal month

month_tier = (
    df.groupBy('Tier', "RenewalMonth")
    .agg(F.count("*").alias("count"))
)
month_tier = month_tier.withColumn(
    "pct",
    F.col("count") / F.sum("count").over(Window.partitionBy("Tier"))
)

pdf = month_tier.orderBy("Tier","RenewalMonth").toPandas()

rand = random.randint(1, 3)

anon_tier_map = {b: f"Tier {chr(65+i*rand)}" for i, b in enumerate(unique_tiers)}
anon_month_map  = {t: f"Renewal Month {chr(65+i*rand)}" for i, t in enumerate(pdf['RenewalMonth'].unique().tolist())}

pdf["month_label"] = pdf["RenewalMonth"].map(anon_month_map)
pdf['Tier'] = pdf['Tier'].map(anon_tier_map)

fig = px.bar(
    pdf,
    x="month_label",
    y="pct",
    color='Tier',
    barmode="stack",
    #text_auto=".1%",
    title="Tier composition by Auto Policy Renewal Month",
    labels={"month_label":"Renewal Month", "pct":"", "Tier":"Tier"}
  
)
fig.update_layout(template="plotly_white", height=600, width=900, showlegend=False,yaxis=dict(showticklabels=False),)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.12.1.min.js"></script>                <div id="b49b44c8-891f-47c5-901e-37288f6e19e9" class="plotly-graph-div" style="height:600px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b49b44c8-891f-47c5-901e-37288f6e19e9")) {                    Plotly.newPlot(                        "b49b44c8-891f-47c5-901e-37288f6e19e9",                        [{"alignmentgroup":"True","hovertemplate":"Tier=Tier C<br>Renewal Month=%{x}<br>=%{y}<extra></extra>","legendgroup":"Tier C","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Tier C","offsetgroup":"Tier C","orientation":"v","showlegend":true,"textposition":"auto","x":["Renewal Month A","Renewal Month C","Renewal Month E","Renewal Month G","Renewal Month I","Renewal Month K","Renewal Month M","Renewal Month O","Renewal Month Q","Renewal Month S","Renewal Month U","Renewal Month W"],"xaxis":"x","y":[0.07734932876321052,0.07814390693568071,0.0900262262730129,0.0927838799304095,0.09148035626184726,0.08485367816987355,0.08304640232660798,0.08643764119342526,0.08278154293578457,0.07972786995923242,0.07849185946872322,0.0748773077821921],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tier=Tier G<br>Renewal Month=%{x}<br>=%{y}<extra></extra>","legendgroup":"Tier G","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Tier G","offsetgroup":"Tier G","orientation":"v","showlegend":true,"textposition":"auto","x":["Renewal Month A","Renewal Month C","Renewal Month E","Renewal Month G","Renewal Month I","Renewal Month K","Renewal Month M","Renewal Month O","Renewal Month Q","Renewal Month S","Renewal Month U","Renewal Month W"],"xaxis":"x","y":[0.08585274930102517,0.094762348555452,0.09282385834109973,0.08812674743709227,0.08477166821994409,0.07567567567567568,0.08167753960857409,0.07910531220876048,0.07567567567567568,0.07888164026095061,0.07932898415657036,0.08331780055917987],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tier=Tier A<br>Renewal Month=%{x}<br>=%{y}<extra></extra>","legendgroup":"Tier A","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Tier A","offsetgroup":"Tier A","orientation":"v","showlegend":true,"textposition":"auto","x":["Renewal Month A","Renewal Month C","Renewal Month E","Renewal Month G","Renewal Month I","Renewal Month K","Renewal Month M","Renewal Month O","Renewal Month Q","Renewal Month S","Renewal Month U","Renewal Month W"],"xaxis":"x","y":[0.08164950867221185,0.08304772805608486,0.08746349997073494,0.08853655205603284,0.08723588286173237,0.08189013247315743,0.08687169548732823,0.08942751045412865,0.08046589970539843,0.07850839256797622,0.07907418366749693,0.07582901402771726],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tier=Tier I<br>Renewal Month=%{x}<br>=%{y}<extra></extra>","legendgroup":"Tier I","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Tier I","offsetgroup":"Tier I","orientation":"v","showlegend":true,"textposition":"auto","x":["Renewal Month A","Renewal Month C","Renewal Month E","Renewal Month G","Renewal Month I","Renewal Month K","Renewal Month M","Renewal Month O","Renewal Month Q","Renewal Month S","Renewal Month U","Renewal Month W"],"xaxis":"x","y":[0.07950208443426693,0.08449298338324232,0.09259585461804944,0.09206740649404029,0.08804532910574835,0.08143972755563385,0.08339204979155658,0.08461041629968881,0.08023604016205743,0.08168927250308261,0.07721214256356057,0.07471669308907286],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tier=Tier E<br>Renewal Month=%{x}<br>=%{y}<extra></extra>","legendgroup":"Tier E","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Tier E","offsetgroup":"Tier E","orientation":"v","showlegend":true,"textposition":"auto","x":["Renewal Month A","Renewal Month C","Renewal Month E","Renewal ...

# %%
# Heatmap - corr between age bucket, income bucket & loss ratio

sdf_demo = df.withColumn("AGE_BUCKET", F.when(F.col("Age_in_One-Year_Increments_-_Person") < 30, "<30")
                                           .when(F.col("Age_in_One-Year_Increments_-_Person") < 50, "30-49")
                                           .when(F.col("Age_in_One-Year_Increments_-_Person") < 70, "50-69")
                                           .otherwise("70+"))

heat = (sdf_demo.groupBy("AGE_BUCKET", "Income_-_Estimated_Household_-_Broad_Ranges")
         .agg(F.mean("LossRatio").alias("avg_loss_ratio"))
         .toPandas())

# --- ANONYMIZE LABELS ---
u_a = heat["AGE_BUCKET"].unique().tolist()
u_i = heat["Income_-_Estimated_Household_-_Broad_Ranges"].unique().tolist()

u_a_map = {b: f"Age Group {chr(65+i*rand)}" for i, b in enumerate(u_a)}
u_i_map  = {t: f"Income Group {chr(65+i*rand)}" for i, t in enumerate(u_i)}

heat["age_anon"] = heat["AGE_BUCKET"].map(u_a_map)
heat["inc_anon"] = heat["Income_-_Estimated_Household_-_Broad_Ranges"].map(u_i_map)

fig = px.density_heatmap(heat, x="inc_anon", y="age_anon",
                         z="avg_loss_ratio", color_continuous_scale="Viridis",
                         labels={"age_anon":"Age Group", "inc_anon":"Income Group"}
                         #title="Average Loss Ratio by Age × Income Group"
                         )
fig.update_layout(template="plotly_white", height=500,  )#  xaxis=dict(showticklabels=False),
                 #  yaxis=dict(showticklabels=False))

fig.update_coloraxes(

        colorbar=dict(
            title="",
            tickvals=[heat["avg_loss_ratio"].min(), heat['avg_loss_ratio'].max()],
            ticktext=["Low", "High"],
            ticks='outside',
            showticklabels=True)
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.12.1.min.js"></script>                <div id="7da66d1c-fa08-4005-8e47-a32a64250176" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7da66d1c-fa08-4005-8e47-a32a64250176")) {                    Plotly.newPlot(                        "7da66d1c-fa08-4005-8e47-a32a64250176",                        [{"coloraxis":"coloraxis","histfunc":"sum","hovertemplate":"Income Group=%{x}<br>Age Group=%{y}<br>sum of avg_loss_ratio=%{z}<extra></extra>","name":"","x":["Income Group A","Income Group C","Income Group E","Income Group G","Income Group G","Income Group I","Income Group K","Income Group M","Income Group M","Income Group O","Income Group A","Income Group I","Income Group I","Income Group M","Income Group Q","Income Group K","Income Group Q","Income Group S","Income Group O","Income Group G","Income Group S","Income Group G","Income Group O","Income Group C","Income Group S","Income Group C","Income Group Q","Income Group A","Income Group E","Income Group K","Income Group K","Income Group A","Income Group O","Income Group M","Income Group C","Income Group E","Income Group I","Income Group S","Income Group Q","Income Group E"],"xaxis":"x","xbingroup":"x","y":["Age Group A","Age Group A","Age Group C","Age Group E","Age Group A","Age Group C","Age Group G","Age Group C","Age Group E","Age Group E","Age Group E","Age Group G","Age Group E","Age Group G","Age Group E","Age Group A","Age Group G","Age Group C","Age Group C","Age Group G","Age Group A","Age Group C","Age Group A","Age Group E","Age Group G","Age Group G","Age Group C","Age Group G","Age Group G","Age Group E","Age Group C","Age Group C","Age Group G","Age Group A","Age Group C","Age Group E","Age Group A","Age Group E","Age Group A","Age Group A"],"yaxis":"y","ybingroup":"y","z":[0.08699381377541018,0.08401222531786749,0.12013936312738974,0.12852560328169194,0.08993082965769478,0.11811207473573372,0.12534835373418213,0.11246626374737365,0.10207018599310114,0.12043342933197752,0.1314965089142466,0.13251791487141995,0.13876847760334962,0.13726142276962902,0.14406636991132912,0.07763134423609233,0.12677974381264193,0.10194216303449659,0.12322965620014711,0.11572339440032517,0.07781667318369832,0.11238400904500263,0.0737600588888541,0.12347371109944733,0.11092803338271344,0.1220409986223312,0.16453931388248696,0.1256647241690964,0.12790424497900055,0.13491568381127522,0.11755735374695823,0.11058284461470658,0.1331608048698629,0.0845437649055699,0.11663636638787518,0.1394973023801927,0.07324135426272022,0.12632413789132158,0.07513279040762659,0.12018752299417942],"type":"histogram2d"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f ...

# %%
cols = ['XXX', 'XXX', 'XXX', 'XXX']

TARGET  = "LossRatio"

overall_mean = geo_pd["LossRatio"].mean()

for CAT_COL in cols:
    agg = (df.groupBy(CAT_COL)
            .agg(F.count("*").alias("n"),
                F.mean(TARGET).alias("avg_loss"))
            .withColumn("pct", F.col("n") / F.sum("n").over(Window.rowsBetween(Window.unboundedPreceding, Window.unboundedFollowing)))
            .orderBy(F.desc("n"))
            .toPandas())

    fig = px.scatter(
        agg, x="pct", y="avg_loss", size="n", color="avg_loss", size_max = 60,
        hover_data=[CAT_COL],
        color_continuous_scale='turbo',
        labels={"pct":"Segmentation Distribution","avg_loss":"Average Loss Ratio"}
    )
    fig.update_layout(

                    xaxis=dict(showticklabels=False),
                    yaxis=dict(showticklabels=False),
                    height=600,
                    width=1000
                    )


    fig.add_hline(y=overall_mean, line_color="black", line_dash="dash",
                annotation_text="Overall mean", annotation_position="top right")
    
    fig.update_coloraxes(

        colorbar=dict(
            title="",
            tickvals=[agg["avg_loss"].min(), agg['avg_loss'].max()],
            ticktext=["Low", "High"],
            ticks='outside',
            showticklabels=True)
)
    
    fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.12.1.min.js"></script>                <div id="88f34149-66b6-4ec1-9152-09872ce44620" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("88f34149-66b6-4ec1-9152-09872ce44620")) {                    Plotly.newPlot(                        "88f34149-66b6-4ec1-9152-09872ce44620",                        [{"customdata":[["16E"],["20M"],["14E"],["17E"],["09C"],["13E"],["21M"],["18E"],["07C"],["06C"],["15E"],["10C"],["11E"],["03Y"],["19M"],["08C"],["05C"],["23M"],["02Y"],[null],["22M"],["12E"],["04Y"],["01Y"]],"hovertemplate":"Segmentation Distribution=%{x}<br>Average Loss Ratio=%{marker.color}<br>n=%{marker.size}<br>Personicx_Lifestage_NS_-_Group_Codes=%{customdata[0]}<extra></extra>","legendgroup":"","marker":{"color":[0.10726900518942105,0.1243824676961192,0.1049844717366347,0.11273395714098364,0.11220235440272813,0.11549389711329078,0.12547707027477814,0.13155364659543783,0.11373703221509027,0.12377643748565503,0.12581970358688094,0.12354132408438458,0.13346019693702035,0.09852131594816264,0.14051270980440103,0.1337483274829833,0.1198228962416712,0.11366381031321292,0.1029426775462245,0.11391496252739325,0.13377131144164492,0.12901820451054324,0.09627494538393316,0.09573139441634287],"coloraxis":"coloraxis","size":[95898,88151,67074,44742,29477,29021,28416,24951,22992,17385,12494,10416,7959,7709,7595,7302,6844,6583,5920,4935,4393,2064,1774,920],"sizemode":"area","sizeref":26.638333333333332,"symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[0.17924357261011373,0.16476360475874507,0.12536844761361832,0.08362756184406045,0.05509565152378905,0.05424333897180453,0.05311252955524611,0.046636075624047924,0.04297449604216704,0.03249441604440997,0.023352616281786493,0.019468613029541226,0.014876218423782511,0.014408941805369942,0.014195863667373812,0.013648215470594282,0.012792164705662457,0.012304327916039737,0.011065110324009607,0.00922404044746409,0.008210984738745642,0.00385783576161416,0.0033157948842555815,0.0017195779557582498],"xaxis":"x","y":[0.10726900518942105,0.1243824676961192,0.1049844717366347,0.11273395714098364,0.11220235440272813,0.11549389711329078,0.12547707027477814,0.13155364659543783,0.11373703221509027,0.12377643748565503,0.12581970358688094,0.12354132408438458,0.13346019693702035,0.09852131594816264,0.14051270980440103,0.1337483274829833,0.1198228962416712,0.11366381031321292,0.1029426775462245,0.11391496252739325,0.13377131144164492,0.12901820451054324,0.09627494538393316,0.09573139441634287],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26" ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.12.1.min.js"></script>                <div id="c4dd31b5-d766-41e2-8e6f-357a2b16de99" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c